# %%
import torch
import torchvision
import torchaudio
import pandas as pd
import sklearn
import tqdm
import timm
from importlib.metadata import version

print("torch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
print("torchaudio version:", torchaudio.__version__)
print("pandas version:", pd.__version__)
print("scikit-learn version:", sklearn.__version__)
print("tqdm version:", tqdm.__version__)
print("timm version:", timm.__version__)

# 또는 importlib.metadata.version을 사용
print("torch version:", version("torch"))
print("torchvision version:", version("torchvision"))
print("torchaudio version:", version("torchaudio"))
print("pandas version:", version("pandas"))
print("scikit-learn version:", version("scikit-learn"))
print("tqdm version:", version("tqdm"))
print("timm version:", version("timm"))
# Out:
# torch version: 2.3.0+cu121
# torchvision version: 0.18.0+cu121
# torchaudio version: 2.3.0+cu121
# pandas version: 1.5.0
# scikit-learn version: 1.3.2
# tqdm version: 4.66.1
# timm version: 0.9.12
# torch version: 2.3.0+cu121
# torchvision version: 0.18.0+cu121
# torchaudio version: 2.3.0+cu121
# pandas version: 1.5.0
# scikit-learn version: 1.3.2
# tqdm version: 4.66.1
# timm version: 0.9.12

# %%
# !nvidia-smi
# Out:
# Sat May  4 19:40:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.80                 Driver Version: 546.80       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   40C    P8              10W /  40W |    380MiB /  6144MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# https://pytorch.org/get-started/locally/#supported-windows-distributions
#
# ![image.png](attachment:image.png)

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.18.0%2Bcu121-cp311-cp311-win_amd64.whl (5.7 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torchaudio-2.3.0%2Bcu121-cp311-cp311-win_amd64.whl (4.1 MB)
# ...

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
# Out:
# CUDA Available: True
